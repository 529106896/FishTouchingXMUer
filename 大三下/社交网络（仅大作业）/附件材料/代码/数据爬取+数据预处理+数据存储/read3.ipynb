# %%
import os
import pandas as pd
import warnings
from tqdm import tqdm
import pymysql
from sqlalchemy import create_engine

warnings.filterwarnings('ignore')

# %%
raw_dataframe = pd.read_csv('rawdata_reprocessed.csv', encoding='utf-8')
raw_dataframe
# Out:
#        weibo_username weibo_verification  \
# 0            辣子鸡谁做的好吃                NaN
# 1                远古的刀                NaN
# 2              暮景烟_深浅                NaN
# 3              东辉毅恒传媒                NaN
# 4        在寒蝉鸣泣中等待夏日重现                NaN
# ...               ...                ...
# 132199       币圈大事件123                NaN
# 132200      xiaotuner                NaN
# 132201           股海选时             微博个人认证
# 132202        80生的心在飞                NaN
# 132203         WQ-698                NaN
#
#                                             weibo_content  \
# 0                   好像可以在自己幻想的元宇宙里过一辈子好像已经过完了一辈子双鱼座的脑子要不得
# 1       反正闭关锁宇宙我们将会面临下一次的闭关锁国融入不了全球经济王峻涛跟你们讲我相信这个元宇宙真的...
# 2       周深先生之夜元宇宙周深拥有了生米就像拥有了梦的翅膀卡布叻周深放心飞吧生米永相随时尚先生元宇宙...
# 3       王峻涛其实吧你有空可以再看看这个视频跟你们讲我相信这个元宇宙真的会来虽然不是一下子就到来还需...
# 4                                     敬元宇宙让基尔希斯坦的女朋友的微博视频
# ...                                                   ...
# ...

# %%
engine = create_engine('mysql+pymysql://root:qq6666774@localhost:3306/metaverse', echo=True)
raw_dataframe.to_sql('index_weibodata', engine, index=False, if_exists='append')
# Out:
# 2022-06-11 01:25:57,135 INFO sqlalchemy.engine.Engine SELECT DATABASE()
# 2022-06-11 01:25:57,136 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-06-11 01:25:57,139 INFO sqlalchemy.engine.Engine SELECT @@sql_mode
# 2022-06-11 01:25:57,140 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-06-11 01:25:57,141 INFO sqlalchemy.engine.Engine SELECT @@lower_case_table_names
# 2022-06-11 01:25:57,142 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-06-11 01:25:57,145 INFO sqlalchemy.engine.Engine SELECT COUNT(*) FROM information_schema.tables WHERE table_schema = %(table_schema)s AND table_name = %(table_name)s
# 2022-06-11 01:25:57,145 INFO sqlalchemy.engine.Engine [generated in 0.00055s] {'table_schema': 'metaverse', 'table_name': 'index_weibodata'}
# 2022-06-11 01:25:57,205 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# ...
